# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 747

# %%
# Create an empty list to hold the weather data.
city_data = []

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kalamakion
# City not found. Skipping...
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | vostok
# Processing Record 7 of Set 1 | palanga
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | san jose temascatio
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | hovd
# Processing Record 18 of Set 1 | verkhnevilyuysk
# Processing Record 19 of Set 1 | qiongshan
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | constitucion
# Processing Record 22 of Set 1 | lima
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | port moresby
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | meulaboh
# Processing Record 29 of Set 1 | morki
# Processing Record 30 of Set 1 | srednekolymsk
# Processing Record 31 of Set 1 | qarchak
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | nieuw amsterdam
# Processing Record 34 of Set 1 | sur
# Processing Record 35 of Set 1 | trebukhiv
# Processing Record 36 of Set 1 | klaksvik
# Processing Record 37 of Set 1 | lumeje
# Processing Record 38 of Set 1 | ixtapa
# Processing Record 39 of Set 1 | homer
# Processing Record 40 of Set 1 | aasiaat
# Processing Record 41 of Set 1 | san quintin
# Processing Record 42 of Set 1 | leningradskiy
# Processing Record 43 of Set 1 | batemans bay
# Processing Record 44 of Set 1 | buritis
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | ambilobe
# Processing Record 3 of Set 2 | warrnambool
# Processing Record 4 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 5 of Set 2 | manaus
# Processing Record 6 of Set 2 | umm lajj
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | mariestad
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | tarauaca
# Processing Record 11 of Set 2 | nemuro
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | caxito
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | banda aceh
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | mogadishu
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | gornopravdinsk
# Processing Record 23 of Set 2 | los llanos de aridane
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | port hardy
# Processing Record 27 of Set 2 | port shepstone
# Processing Record 28 of Set 2 | hervey bay
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | san felipe
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 2 | hay river
# Processing Record 35 of Set 2 | mildura
# Processing Record 36 of Set 2 | omsukchan
# Processing Record 37 of Set 2 | gaomi
# Processing Record 38 of Set 2 | hami
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | waingapu
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | hukuntsi
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | luau
# Processing Record 47 of Set 2 | ambulu
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | selma
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | balikpapan
# Processing Record 2 of Set 3 | mirai
# Processing Record 3 of Set 3 | sai buri
# Processing Record 4 of Set 3 | ust-barguzin
# Processing Record 5 of Set 3 | bambanglipuro
# Processing Record 6 of Set 3 | hofn
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | waterbury
# Processing Record 10 of Set 3 | northam
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | inirida
# Processing Record 15 of Set 3 | general roca
# Processing Record 16 of Set 3 | kamloops
# Processing Record 17 of Set 3 | green river
# Processing Record 18 of Set 3 | ghorawal
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | kirakira
# Processing Record 21 of Set 3 | porto velho
# Processing Record 22 of Set 3 | iquique
# Processing Record 23 of Set 3 | sungairaya
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | sauce
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | shush
# Processing Record 28 of Set 3 | batagay-alyta
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | mataura
# Processing Record 31 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 3 | sorland
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | fort frances
# Processing Record 35 of Set 3 | octeville
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | conde
# Processing Record 38 of Set 3 | cambyreta
# City not found. Skipping...
# Processing Record 39 of Set 3 | chara
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | berlin
# Processing Record 42 of Set 3 | conneaut
# Processing Record 43 of Set 3 | neuquen
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | xixiang
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | linhares
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 4 | cap malheureux
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | cozumel
# Processing Record 4 of Set 4 | skegness
# Processing Record 5 of Set 4 | pozo colorado
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | fussen
# Processing Record 9 of Set 4 | baymak
# Processing Record 10 of Set 4 | dwarka
# Processing Record 11 of Set 4 | mokhsogollokh
# Processing Record 12 of Set 4 | poopo
# Processing Record 13 of Set 4 | wisla
# Processing Record 14 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 4 | le port
# Processing Record 16 of Set 4 | bure
# Processing Record 17 of Set 4 | malangali
# Processing Record 18 of Set 4 | ingham
# Processing Record 19 of Set 4 | nusaybin
# Processing Record 20 of Set 4 | tres picos
# Processing Record 21 of Set 4 | punta cardon
# Processing Record 22 of Set 4 | clyde river
# Processing Record 23 of Set 4 | bathsheba
# Processing Record 24 of Set 4 | bolshaya irba
# City not found. Skipping...
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | nichinan
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | neubrandenburg
# Processing Record 29 of Set 4 | porto novo
# Processing Record 30 of Set 4 | kavieng
# Processing Record 31 of Set 4 | la ronge
# Processing Record 32 of Set 4 | tezu
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | camacha
# Processing Record 36 of Set 4 | mbuji-mayi
# Processing Record 37 of Set 4 | togur
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | qujing
# Processing Record 40 of Set 4 | simao
# Processing Record 41 of Set 4 | lakes entrance
# Processing Record 42 of Set 4 | kitimat
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | brunico
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | restrepo
# Processing Record 47 of Set 4 | naryan-mar
# Processing Record 48 of Set 4 | unity
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | moiyabana
# City not found. Skipping...
# Processing Record 4 of Set 5 | mount isa
# Processing Record 5 of Set 5 | okhotsk
# Processing Record 6 of Set 5 | high rock
# Processing Record 7 of Set 5 | lecce
# Processing Record 8 of Set 5 | barrow
# Processing Record 9 of Set 5 | sambava
# Processing Record 10 of Set 5 | pishin
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | ojinaga
# Processing Record 14 of Set 5 | sabang
# Processing Record 15 of Set 5 | vitim
# Processing Record 16 of Set 5 | jacutinga
# Processing Record 17 of Set 5 | pangnirtung
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | bluff
# Processing Record 20 of Set 5 | castro
# Processing Record 21 of Set 5 | tamandare
# Processing Record 22 of Set 5 | vega de alatorre
# Processing Record 23 of Set 5 | mattru
# Processing Record 24 of Set 5 | mikun
# Processing Record 25 of Set 5 | vanavara
# Processing Record 26 of Set 5 | quatre cocos
# Processing Record 27 of Set 5 | vzmorye
# Processing Record 28 of Set 5 | santa pola
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | belmonte
# Processing Record 31 of Set 5 | tura
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | laguna
# Processing Record 34 of Set 5 | barahona
# Processing Record 35 of Set 5 | turka
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 5 | lysyanka
# Processing Record 39 of Set 5 | cabedelo
# Processing Record 40 of Set 5 | salalah
# Processing Record 41 of Set 5 | santa rosa
# Processing Record 42 of Set 5 | lompoc
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | araouane
# Processing Record 46 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 5 | borogontsy
# Processing Record 48 of Set 5 | breytovo
# Processing Record 49 of Set 5 | faya
# Processing Record 50 of Set 5 | fort-shevchenko
# Processing Record 1 of Set 6 | mount gambier
# Processing Record 2 of Set 6 | mahaicony
# City not found. Skipping...
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | tiksi
# Processing Record 5 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 6 | suntar
# Processing Record 8 of Set 6 | upernavik
# Processing Record 9 of Set 6 | mangai
# Processing Record 10 of Set 6 | norman wells
# Processing Record 11 of Set 6 | souillac
# Processing Record 12 of Set 6 | egvekinot
# Processing Record 13 of Set 6 | goundam
# Processing Record 14 of Set 6 | port macquarie
# Processing Record 15 of Set 6 | queimadas
# Processing Record 16 of Set 6 | takoradi
# Processing Record 17 of Set 6 | namatanai
# Processing Record 18 of Set 6 | greenville
# Processing Record 19 of Set 6 | sterling
# Processing Record 20 of Set 6 | valparaiso
# Processing Record 21 of Set 6 | eureka
# Processing Record 22 of Set 6 | ayia galini
# Processing Record 23 of Set 6 | bashtanka
# Processing Record 24 of Set 6 | verkhoyansk
# Processing Record 25 of Set 6 | george
# Processing Record 26 of Set 6 | yichun
# Processing Record 27 of Set 6 | hongjiang
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | vestmannaeyjar
# Processing Record 31 of Set 6 | betsiamites
# Processing Record 32 of Set 6 | corinth
# Processing Record 33 of Set 6 | cabo san lucas
# Processing Record 34 of Set 6 | honiara
# Processing Record 35 of Set 6 | cayenne
# Processing Record 36 of Set 6 | tessalit
# Processing Record 37 of Set 6 | west lafayette
# Processing Record 38 of Set 6 | thanjavur
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 6 | safranbolu
# Processing Record 43 of Set 6 | dakar
# Processing Record 44 of Set 6 | lampang
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | caibarien
# Processing Record 47 of Set 6 | khatanga
# Processing Record 48 of Set 6 | sitka
# Processing Record 49 of Set 6 | arrecife
# Processing Record 50 of Set 6 | berlevag
# Processing Record 1 of Set 7 | nome
# Processing Record 2 of Set 7 | barsovo
# Processing Record 3 of Set 7 | kemijarvi
# Processing Record 4 of Set 7 | ponta do sol
# Processing Record 5 of Set 7 | mandan
# Processing Record 6 of Set 7 | vicuna
# Processing Record 7 of Set 7 | waipawa
# Processing Record 8 of Set 7 | rigaud
# Processing Record 9 of Set 7 | williams lake
# Processing Record 10 of Set 7 | axim
# Processing Record 11 of Set 7 | emerald
# Processing Record 12 of Set 7 | paraiso
# Processing Record 13 of Set 7 | santa maria
# Processing Record 14 of Set 7 | tanabe
# Processing Record 15 of Set 7 | kawalu
# Processing Record 16 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | koroni
# Processing Record 19 of Set 7 | jega
# Processing Record 20 of Set 7 | agva
# City not found. Skipping...
# Processing Record 21 of Set 7 | vizimyary
# City not found. Skipping...
# Processing Record 22 of Set 7 | fengkou
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | pauini
# Processing Record 25 of Set 7 | isangel
# Processing Record 26 of Set 7 | oxilithos
# Processing Record 27 of Set 7 | pundaguitan
# Processing Record 28 of Set 7 | bannu
# Processing Record 29 of Set 7 | brigantine
# Processing Record 30 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 7 | zhigansk
# Processing Record 32 of Set 7 | virden
# Processing Record 33 of Set 7 | ferrol
# Processing Record 34 of Set 7 | arsk
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | karratha
# Processing Record 37 of Set 7 | saint-louis
# Processing Record 38 of Set 7 | santiago del estero
# Processing Record 39 of Set 7 | bonavista
# Processing Record 40 of Set 7 | mednogorskiy
# Processing Record 41 of Set 7 | yulara
# Processing Record 42 of Set 7 | achacachi
# Processing Record 43 of Set 7 | zelenoborsk
# Processing Record 44 of Set 7 | kommunisticheskiy
# Processing Record 45 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | novosemeykino
# Processing Record 48 of Set 7 | lishan
# Processing Record 49 of Set 7 | cabinda
# Processing Record 50 of Set 7 | oranjemund
# Processing Record 1 of Set 8 | sovetskiy
# Processing Record 2 of Set 8 | batagay
# Processing Record 3 of Set 8 | sciacca
# Processing Record 4 of Set 8 | dunda
# Processing Record 5 of Set 8 | talnakh
# Processing Record 6 of Set 8 | lebyazhye
# Processing Record 7 of Set 8 | mutsu
# Processing Record 8 of Set 8 | kahului
# Processing Record 9 of Set 8 | mapastepec
# Processing Record 10 of Set 8 | yatou
# Processing Record 11 of Set 8 | rawlins
# Processing Record 12 of Set 8 | notre-dame-du-lac
# Processing Record 13 of Set 8 | bandarbeyla
# Processing Record 14 of Set 8 | filingue
# Processing Record 15 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 16 of Set 8 | ancud
# Processing Record 17 of Set 8 | ekhabi
# Processing Record 18 of Set 8 | hithadhoo
# Processing Record 19 of Set 8 | dunedin
# Processing Record 20 of Set 8 | benguela
# Processing Record 21 of Set 8 | bereda
# Processing Record 22 of Set 8 | grabouw
# Processing Record 23 of Set 8 | kloulklubed
# Processing Record 24 of Set 8 | rio grande
# Processing Record 25 of Set 8 | iskateley
# Processing Record 26 of Set 8 | quirinopolis
# Processing Record 27 of Set 8 | hailar
# Processing Record 28 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 8 | porto seguro
# Processing Record 30 of Set 8 | shaowu
# Processing Record 31 of Set 8 | yar-sale
# Processing Record 32 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 33 of Set 8 | chhatak
# Processing Record 34 of Set 8 | chippewa falls
# Processing Record 35 of Set 8 | kwinana
# Processing Record 36 of Set 8 | balabac
# Processing Record 37 of Set 8 | brazzaville
# Processing Record 38 of Set 8 | sao felix do xingu
# Processing Record 39 of Set 8 | saint-joseph
# Processing Record 40 of Set 8 | kolokani
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | toppenish
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | college
# Processing Record 45 of Set 8 | grafenhainichen
# Processing Record 46 of Set 8 | netanya
# Processing Record 47 of Set 8 | hearst
# Processing Record 48 of Set 8 | russell
# Processing Record 49 of Set 8 | olds
# Processing Record 50 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 9 | ukiah
# Processing Record 2 of Set 9 | mareeba
# Processing Record 3 of Set 9 | narsaq
# Processing Record 4 of Set 9 | urucara
# Processing Record 5 of Set 9 | ialibu
# Processing Record 6 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 9 | panuco
# Processing Record 8 of Set 9 | veshkayma
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | makhinjauri
# Processing Record 11 of Set 9 | soe
# Processing Record 12 of Set 9 | surgut
# Processing Record 13 of Set 9 | grenville
# Processing Record 14 of Set 9 | crossville
# Processing Record 15 of Set 9 | padang
# Processing Record 16 of Set 9 | lasa
# Processing Record 17 of Set 9 | guarapari
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | emborion
# Processing Record 21 of Set 9 | mayumba
# Processing Record 22 of Set 9 | chernyshevskiy
# Processing Record 23 of Set 9 | abnub
# Processing Record 24 of Set 9 | lumphat
# Processing Record 25 of Set 9 | mocuba
# Processing Record 26 of Set 9 | montepuez
# Processing Record 27 of Set 9 | masoko
# Processing Record 28 of Set 9 | kurilsk
# Processing Record 29 of Set 9 | kavaratti
# Processing Record 30 of Set 9 | athmallik
# Processing Record 31 of Set 9 | gazanjyk
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | malakal
# Processing Record 34 of Set 9 | victoria
# Processing Record 35 of Set 9 | tucumcari
# Processing Record 36 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 37 of Set 9 | tual
# Processing Record 38 of Set 9 | rabinal
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | humaita
# Processing Record 41 of Set 9 | aripuana
# Processing Record 42 of Set 9 | namibe
# Processing Record 43 of Set 9 | bermejo
# Processing Record 44 of Set 9 | oksfjord
# Processing Record 45 of Set 9 | kaitangata
# Processing Record 46 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 9 | pavlodar
# Processing Record 49 of Set 9 | houma
# Processing Record 50 of Set 9 | dingle
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | ilulissat
# Processing Record 3 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 4 of Set 10 | new orleans
# Processing Record 5 of Set 10 | kruisfontein
# Processing Record 6 of Set 10 | arnprior
# Processing Record 7 of Set 10 | alcantara
# Processing Record 8 of Set 10 | darhan
# Processing Record 9 of Set 10 | pultusk
# Processing Record 10 of Set 10 | henties bay
# Processing Record 11 of Set 10 | jaisalmer
# Processing Record 12 of Set 10 | acarau
# Processing Record 13 of Set 10 | hambantota
# Processing Record 14 of Set 10 | muzaffargarh
# Processing Record 15 of Set 10 | faaborg
# Processing Record 16 of Set 10 | aykhal
# Processing Record 17 of Set 10 | rumford
# Processing Record 18 of Set 10 | nishihara
# Processing Record 19 of Set 10 | olinda
# Processing Record 20 of Set 10 | hajnowka
# Processing Record 21 of Set 10 | gamboma
# Processing Record 22 of Set 10 | fano
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | cockburn town
# Processing Record 25 of Set 10 | port lincoln
# Processing Record 26 of Set 10 | luderitz
# Processing Record 27 of Set 10 | lake havasu city
# Processing Record 28 of Set 10 | severo-yeniseyskiy
# Processing Record 29 of Set 10 | san jose
# Processing Record 30 of Set 10 | hamilton
# Processing Record 31 of Set 10 | labuhan
# Processing Record 32 of Set 10 | bonfim
# Processing Record 33 of Set 10 | alofi
# Processing Record 34 of Set 10 | uige
# Processing Record 35 of Set 10 | sampit
# Processing Record 36 of Set 10 | mozarlandia
# Processing Record 37 of Set 10 | madan
# Processing Record 38 of Set 10 | iwanai
# Processing Record 39 of Set 10 | moose factory
# Processing Record 40 of Set 10 | san pietro in casale
# Processing Record 41 of Set 10 | turayf
# Processing Record 42 of Set 10 | ternate
# Processing Record 43 of Set 10 | noumea
# Processing Record 44 of Set 10 | abu samrah
# Processing Record 45 of Set 10 | cam ranh
# Processing Record 46 of Set 10 | coahuayana
# Processing Record 47 of Set 10 | parainen
# Processing Record 48 of Set 10 | vao
# Processing Record 49 of Set 10 | burns lake
# Processing Record 50 of Set 10 | codrington
# Processing Record 1 of Set 11 | sawai madhopur
# Processing Record 2 of Set 11 | nabire
# Processing Record 3 of Set 11 | rawson
# Processing Record 4 of Set 11 | peterhead
# Processing Record 5 of Set 11 | lavrentiya
# Processing Record 6 of Set 11 | saint-pierre
# Processing Record 7 of Set 11 | champerico
# Processing Record 8 of Set 11 | vila
# Processing Record 9 of Set 11 | makakilo city
# Processing Record 10 of Set 11 | tilichiki
# Processing Record 11 of Set 11 | el copey
# Processing Record 12 of Set 11 | kununurra
# Processing Record 13 of Set 11 | nelson bay
# Processing Record 14 of Set 11 | shingu
# Processing Record 15 of Set 11 | lola
# Processing Record 16 of Set 11 | merauke
# Processing Record 17 of Set 11 | general salgado
# Processing Record 18 of Set 11 | stepnyak
# Processing Record 19 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 11 | beyneu
# Processing Record 21 of Set 11 | lagos
# Processing Record 22 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 11 | badvel
# Processing Record 24 of Set 11 | linchuan
# City not found. Skipping...
# Processing Record 25 of Set 11 | abay
# Processing Record 26 of Set 11 | backi jarak
# Processing Record 27 of Set 11 | westport
# Processing Record 28 of Set 11 | hohhot
# Processing Record 29 of Set 11 | nkhotakota
# Processing Record 30 of Set 11 | adrar
# Processing Record 31 of Set 11 | gravdal
# Processing Record 32 of Set 11 | ossora
# Processing Record 33 of Set 11 | horta
# Processing Record 34 of Set 11 | malchin
# Processing Record 35 of Set 11 | antalaha
# Processing Record 36 of Set 11 | richards bay
# Processing Record 37 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 11 | tautira
# Processing Record 39 of Set 11 | katangli
# Processing Record 40 of Set 11 | catuday
# Processing Record 41 of Set 11 | diamantino
# Processing Record 42 of Set 11 | mayo
# Processing Record 43 of Set 11 | strezhevoy
# Processing Record 44 of Set 11 | jumla
# Processing Record 45 of Set 11 | tommot
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | vila franca do campo
# Processing Record 48 of Set 11 | churapcha
# Processing Record 49 of Set 11 | cabra
# Processing Record 50 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 12 | elbistan
# Processing Record 2 of Set 12 | ampanihy
# Processing Record 3 of Set 12 | oyama
# Processing Record 4 of Set 12 | gilgit
# Processing Record 5 of Set 12 | marsaxlokk
# Processing Record 6 of Set 12 | haikou
# Processing Record 7 of Set 12 | burica
# City not found. Skipping...
# Processing Record 8 of Set 12 | mezen
# Processing Record 9 of Set 12 | teknaf
# Processing Record 10 of Set 12 | kenai
# Processing Record 11 of Set 12 | korla
# Processing Record 12 of Set 12 | bilma
# Processing Record 13 of Set 12 | marsa matruh
# Processing Record 14 of Set 12 | ruidoso
# Processing Record 15 of Set 12 | zhigalovo
# Processing Record 16 of Set 12 | cheremshan
# Processing Record 17 of Set 12 | port hedland
# Processing Record 18 of Set 12 | sawtell
# Processing Record 19 of Set 12 | luanda
# Processing Record 20 of Set 12 | orlik
# Processing Record 21 of Set 12 | isiro
# Processing Record 22 of Set 12 | fort smith
# Processing Record 23 of Set 12 | kango
# Processing Record 24 of Set 12 | monrovia
# Processing Record 25 of Set 12 | cayce
# Processing Record 26 of Set 12 | hirado
# Processing Record 27 of Set 12 | hof
# Processing Record 28 of Set 12 | oktyabrskiy
# Processing Record 29 of Set 12 | kangaatsiaq
# Processing Record 30 of Set 12 | lubao
# Processing Record 31 of Set 12 | mahibadhoo
# Processing Record 32 of Set 12 | subang
# Processing Record 33 of Set 12 | say
# Processing Record 34 of Set 12 | kumluca
# Processing Record 35 of Set 12 | broome
# Processing Record 36 of Set 12 | deputatskiy
# Processing Record 37 of Set 12 | ayotzintepec
# Processing Record 38 of Set 12 | ahipara
# Processing Record 39 of Set 12 | malpura
# Processing Record 40 of Set 12 | tahta
# Processing Record 41 of Set 12 | salinopolis
# Processing Record 42 of Set 12 | katsuura
# Processing Record 43 of Set 12 | wajir
# Processing Record 44 of Set 12 | quixeramobim
# Processing Record 45 of Set 12 | barra do garcas
# Processing Record 46 of Set 12 | sao jose de ribamar
# Processing Record 47 of Set 12 | grobenzell
# Processing Record 48 of Set 12 | ust-karsk
# Processing Record 49 of Set 12 | bingol
# Processing Record 50 of Set 12 | progreso
# Processing Record 1 of Set 13 | krasnoselkup
# Processing Record 2 of Set 13 | jatai
# Processing Record 3 of Set 13 | murray bridge
# Processing Record 4 of Set 13 | grand-santi
# Processing Record 5 of Set 13 | provideniya
# Processing Record 6 of Set 13 | demir kapija
# Processing Record 7 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 13 | coquimbo
# Processing Record 9 of Set 13 | turukhansk
# Processing Record 10 of Set 13 | seoul
# Processing Record 11 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 12 of Set 13 | pacific grove
# Processing Record 13 of Set 13 | takestan
# Processing Record 14 of Set 13 | guapi
# Processing Record 15 of Set 13 | davila
# Processing Record 16 of Set 13 | kang
# Processing Record 17 of Set 13 | carbonear
# Processing Record 18 of Set 13 | corpus christi
# Processing Record 19 of Set 13 | xinyang
# Processing Record 20 of Set 13 | nouadhibou
# Processing Record 21 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 22 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 13 | flinders
# Processing Record 24 of Set 13 | llanelli
# Processing Record 25 of Set 13 | constantine
# Processing Record 26 of Set 13 | sao sebastiao
# Processing Record 27 of Set 13 | kyshtovka
# Processing Record 28 of Set 13 | troitskoye
# Processing Record 29 of Set 13 | bethanien
# Processing Record 30 of Set 13 | conchas
# Processing Record 31 of Set 13 | hantsport
# Processing Record 32 of Set 13 | teeli
# Processing Record 33 of Set 13 | concarneau
# Processing Record 34 of Set 13 | atasu
# Processing Record 35 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 36 of Set 13 | lebedyn
# Processing Record 37 of Set 13 | gudivada
# Processing Record 38 of Set 13 | saint anthony
# Processing Record 39 of Set 13 | grenada
# Processing Record 40 of Set 13 | sabha
# Processing Record 41 of Set 13 | ermelo
# Processing Record 42 of Set 13 | tocopilla
# Processing Record 43 of Set 13 | mounana
# Processing Record 44 of Set 13 | aleksin
# Processing Record 45 of Set 13 | mitu
# Processing Record 46 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 13 | aquin
# Processing Record 48 of Set 13 | tevriz
# Processing Record 49 of Set 13 | malinovoye ozero
# Processing Record 50 of Set 13 | serebryanyy bor
# Processing Record 1 of Set 14 | pecos
# Processing Record 2 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 3 of Set 14 | shetpe
# Processing Record 4 of Set 14 | nhulunbuy
# Processing Record 5 of Set 14 | bayan
# Processing Record 6 of Set 14 | sangar
# Processing Record 7 of Set 14 | toccoa
# Processing Record 8 of Set 14 | nikolsk
# Processing Record 9 of Set 14 | zadar
# Processing Record 10 of Set 14 | mweka
# Processing Record 11 of Set 14 | songjianghe
# Processing Record 12 of Set 14 | tiarei
# Processing Record 13 of Set 14 | ndele
# Processing Record 14 of Set 14 | mbanza-ngungu
# Processing Record 15 of Set 14 | imeni poliny osipenko
# Processing Record 16 of Set 14 | usinsk
# Processing Record 17 of Set 14 | astipalaia
# City not found. Skipping...
# Processing Record 18 of Set 14 | koilas
# Processing Record 19 of Set 14 | bayonet point
# Processing Record 20 of Set 14 | torbay
# Processing Record 21 of Set 14 | teguise
# Processing Record 22 of Set 14 | larap
# Processing Record 23 of Set 14 | gloucester
# Processing Record 24 of Set 14 | lincoln
# Processing Record 25 of Set 14 | manadhoo
# Processing Record 26 of Set 14 | karaj
# Processing Record 27 of Set 14 | havre
# Processing Record 28 of Set 14 | evensk
# Processing Record 29 of Set 14 | sioux lookout
# Processing Record 30 of Set 14 | tyrma
# Processing Record 31 of Set 14 | bilibino
# Processing Record 32 of Set 14 | fort nelson
# Processing Record 33 of Set 14 | olpad
# Processing Record 34 of Set 14 | grand gaube
# Processing Record 35 of Set 14 | goderich
# Processing Record 36 of Set 14 | bacolod
# Processing Record 37 of Set 14 | lubana
# Processing Record 38 of Set 14 | yumen
# Processing Record 39 of Set 14 | shiyan
# Processing Record 40 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 41 of Set 14 | mukhtolovo
# Processing Record 42 of Set 14 | nizwa
# Processing Record 43 of Set 14 | narrabri
# Processing Record 44 of Set 14 | kjollefjord
# Processing Record 45 of Set 14 | charleston
# Processing Record 46 of Set 14 | yaan
# Processing Record 47 of Set 14 | ntungamo
# Processing Record 48 of Set 14 | juneau
# Processing Record 49 of Set 14 | nagar karnul
# Processing Record 50 of Set 14 | kedrovyy
# Processing Record 1 of Set 15 | qaqortoq
# Processing Record 2 of Set 15 | kaeo
# Processing Record 3 of Set 15 | dongsheng
# Processing Record 4 of Set 15 | bansko
# Processing Record 5 of Set 15 | biak
# Processing Record 6 of Set 15 | cajamarca
# Processing Record 7 of Set 15 | belaya gora
# Processing Record 8 of Set 15 | muroto
# Processing Record 9 of Set 15 | kismayo
# Processing Record 10 of Set 15 | tarsus
# Processing Record 11 of Set 15 | hong gai
# Processing Record 12 of Set 15 | maracacume
# Processing Record 13 of Set 15 | nuuk
# Processing Record 14 of Set 15 | meybod
# Processing Record 15 of Set 15 | gobabis
# Processing Record 16 of Set 15 | the valley
# Processing Record 17 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | mersing
# Processing Record 19 of Set 15 | tanout
# Processing Record 20 of Set 15 | laiagam
# City not found. Skipping...
# Processing Record 21 of Set 15 | cordoba
# Processing Record 22 of Set 15 | santa cruz
# Processing Record 23 of Set 15 | rongcheng
# Processing Record 24 of Set 15 | santa cruz del norte
# Processing Record 25 of Set 15 | sao gabriel da cachoeira
# Processing Record 26 of Set 15 | le mans
# Processing Record 27 of Set 15 | fort saint james
# Processing Record 28 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 15 | do gonbadan
# Processing Record 30 of Set 15 | varkkallai
# Processing Record 31 of Set 15 | vestmanna
# Processing Record 32 of Set 15 | malanje
# Processing Record 33 of Set 15 | pietra ligure
# Processing Record 34 of Set 15 | muzhi
# Processing Record 35 of Set 15 | tyup
# Processing Record 36 of Set 15 | albury
# Processing Record 37 of Set 15 | aviles
# Processing Record 38 of Set 15 | roma
# Processing Record 39 of Set 15 | aurangabad
# Processing Record 40 of Set 15 | reims
# Processing Record 41 of Set 15 | birobidzhan
# Processing Record 42 of Set 15 | ocos
# Processing Record 43 of Set 15 | shimoda
# Processing Record 44 of Set 15 | awjilah
# Processing Record 45 of Set 15 | carutapera
# Processing Record 46 of Set 15 | chlorakas
# Processing Record 47 of Set 15 | longyearbyen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cherskiy      RU  68.7500  161.3000     36.09       100          92
# 1    Punta Arenas      CL -53.1500  -70.9167     37.51        87          40
# 2      Vila Velha      BR -20.3297  -40.2925     75.15        78          40
# 3            Chuy      UY -33.6971  -53.4616     50.50        83          25
# 4          Vostok      RU  46.4856  135.8833     53.20        47         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 683       Shimoda      JP  34.6667  138.9500     66.56        98         100
# 684       Awjilah      LY  29.1081   21.2869     67.37        69          59
# 685    Carutapera      BR  -1.1950  -46.0200     74.68        95          99
# 686     Chlorakas      CY  34.8042   32.4083     65.55        45           0
# 687  Longyearbyen      SJ  78.2186   15.6401     14.81        80          22
#
#      Wind Speed Current Description
# 0         13.31     overcast clouds
# 1          5.75    scattered clouds
# 2         10.36    scattered clouds
# 3          2.66    scattered clouds
# 4          6.60     overcast clouds
# ..          ...                 ...
# 683        6.29          light rain
# 684        3.85          light rain
# 685        3.20     overcast clouds
# 686        0.00           clear sky
# 687        6.26          few clouds
#
# [688 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
